# %%
from __future__ import print_function
import os
from datetime import datetime
from flask import Flask, request,render_template,request,redirect,url_for,after_this_request,make_response,flash,jsonify
from flask import send_from_directory
from functools import wraps
import time
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account

# %%
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# %%
SAMPLE_SPREADSHEET_ID = '1PmzgBadfqBEzlDH5hBfXqe61z0QPp7VsUoUFV6cD'
SAMPLE_RANGE_NAME = 'Loot!A1:D4000'

# %%
import pandas as pd

# %%
SERVICE_ACCOUNT_FILE = 'key.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
credentials = None
credentials = service_account.Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)



    # If modifying these scopes, delete the file token.json.

    # The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = '1PmzgBadfqBEzlDH5hBfXqe61z0QPp7VsUoUFV6cD-do'

    

service = build('sheets', 'v4', credentials=credentials)


    # Call the Sheets API
sheet = service.spreadsheets()
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID, range="Loot!a4:D4200").execute()

# %%
    df = pd.DataFrame.from_records(result, columns=['values'])

# %%
df2= pd.DataFrame(df["values"].to_list(), columns=['Date', 'Player','Item','DKP'])
df2
# Out:
#      Date        Player                      Item  DKP
# 0                Barton              Noth's Heart  130
# 1                Varros  Wristguards of Vengeance  305
# 2          Thuderhammer            Icy Scail Coif    1
# 3                Yumiki       Desecrated Bindings   71
# 4               Dinkkle       Desecrated Bindings   72
# ...   ...           ...                       ...  ...
# 3267               Gyro      Desecrated Gauntlets   18
# 3268             Ismago      Desecrated Pauldrons    6
# 3269             Ismago      Desecrated Legplates    8
# 3270             Ismago         Desecrated Helmet    7
# 3271               Tuko      Desecrated Headpiece    7
#
# [3272 rows x 4 columns]

# %%
df3=df2.sort_values(by=['DKP'],ascending=False )
df3['DKP'] = pd.to_numeric(df3['DKP'], errors='coerce')
df3 = df3.fillna(0)
df3=df3.sort_values(by=['DKP'],ascending=False )
df3['DKP'] =df3['DKP'].astype(int)
df3 = df3.replace(['DFT'],'Drake Fang Talisman')
df3 = df3.replace(['GOA'],'Gauntlets of Annihilation')
df3 = df3.replace(['Gressil, Dawn of RUin'],'Gressil, Dawn of Ruin')
df3 = df3.replace(['Restrained Essence of Sapphiron'],'The Restrained Essence of Sapphiron')
df3 = df3.replace(['rejuv gem'],'Rejuvenating Gem')
df3 = df3.replace(['Rejuvination Gem'],'Rejuvenating Gem')
df3 = df3.replace(['QSR'],'Quick Strike Ring')
df3 = df3.replace(['CTS'],'Chromatically Tempered Sword')
df3 = df3.replace(['Kiss of the SPider'],'Kiss of the Spider')
df3 = df3.replace(['Band of Unnatural FOrces'],'Band of Unnatural Forces')
df3 = df3.replace(['Band of Unnatureal'],'Band of Unnatural Forces')
df3 = df3.replace(['eyestalk waist cord'],'Eyestalk Waist Cord')
df3 = df3.replace(['hammer of the twisting nether'],'Hammer of the Twisting Nether')
df3 = df3.replace(['DOOMFINGER'],'Doomfinger')
df3 = df3.replace(['Shroud of Dominio'],'Shroud of Dominion')
df3 = df3.replace(['Badge of the swarmguard'],'Badge of the Swarmguard')
df3 = df3.replace(['Hammert of the Twisting Nether'],'Hammer of the Twisting Nether')
df3 = df3.replace(['Rejuvinating Gem'],'Rejuvenating Gem')


Badge of the swarmguard


df3.head(100)
df3.to_csv('myfile.csv')

# %%
df3
# Out:
#       Date   Player                       Item   DKP
# 2826  6/28      Bli         The Hungering Cold  1244
# 3144  8/23   Koneko      Gressil, Dawn of Ruin  1235
# 2981  7/26     Bill      Gressil, Dawn of Ruin  1226
# 2956  7/19  Manowar         The Hungering Cold  1223
# 2870   7/5  Dolphin         Kiss of the Spider  1220
# ...    ...      ...                        ...   ...
# 1256                    Nightslayer Chestpiece     0
# 1263                        Legplates of Wrath     0
# 1259                 Bindings of Transcendence     0
# 904                            Stygian Buckler     0
# 3249  8/31                          Biznick's      0
#
# [3272 rows x 4 columns]

# %%
df3.values.tolist()
# Out:
# [['6/28', 'Bli', 'The Hungering Cold', 1244],
#  ['8/23', 'Koneko', 'Gressil, Dawn of Ruin', 1235],
#  ['7/26', 'Bill', 'Gressil, Dawn of Ruin', 1226],
#  ['7/19', 'Manowar', 'The Hungering Cold', 1223],
#  ['7/5', 'Dolphin', 'Kiss of the Spider', 1220],
#  ['6/14', 'Haka', 'Gressil, Dawn of Ruin', 1216],
#  ['5/18', 'Brockstar', "Neltharion's Tear", 1202],
#  ['6/8', 'Iggsy', 'Gauntlets of Annihilation', 1200],
#  ['', 'Clonk', 'The Hungering Cold', 1185],
#  ['8/2', 'Chihua', 'The Hungering Cold', 1180],
#  ['12/28', 'Rogueisme', 'Gressil, Dawn of Ruin', 1171],
#  ['5/31', 'Tunasubgg', "Slayer's Crest", 1169],
#  ['12/22', 'Ahimelech', 'Scarab Brooch', 1134],
#  ['6/21', 'Nineteenxx', "Slayer's Crest", 1127],
#  ['5/10', 'Rogueisme', "Slayer's Crest", 1108],
#  ['1/26', 'Dane', 'Belt of Never-Ending Agony', 1100],
#  ['1/11', 'Tunasubgg', 'Kiss of the Spider', 1095],
#  ['', 'Ismagu', 'Gressil, Dawn of Ruin', 1090],
#  ['7/19', 'Pookster', 'Kiss of the Spider', 1081],
#  ['2/22', 'Mano', 'Kiss of the Spider', 1058],
#  ['8/2', 'Malekk', "Slayer's Crest", 1055],
#  ['6/28', 'Gauss', "Slayer's Crest", 1036],
#  ['2/1', 'Saya', 'Gressil, Dawn of Ruin', 1028],
#  ['1/25', 'Shaq', 'Eye of the Dead', 1015],
#  ['', 'Rowaijne', 'Corrupted Ashbringer', 1000],
#  ['1/11', 'Hadria', 'Eye of the Dead', 1000],
#  ['1/25', 'Rella', 'Kiss of the Spider', 999],
#  ['', 'Virahl', 'Kiss of the Spider', 994],
#  ['4/12', 'Nezzie', 'DOOMFINGER', 993],
#  ['', 'Iggy', "Slayer's Crest", 991],
#  ['7/12', 'Brockstar', 'The Restrained Essence of Sapphiron', 986],
#  ['6/1', 'Hadria', 'Boots of Pure Thought', 970],
#  ['', 'Dane', 'Gressil, Dawn of Ruin', 960],
#  ['12/28', 'Kibbles', 'Rime Covered Mantle', 959],
#  ['3/22', 'Plated', 'Might of Menethil', 955],
#  ['8/10', 'Sobie', 'Drake Fang Talisman', 948],
#  ['2/8', 'Ismagu', 'Kiss of the Spider', 936],
#  ['12/29', 'Keen', "Neltharion's Tear", 932],
#  ['2/8', 'Kazik', 'Band of Unnatural Forces', 917],
#  ['6/21', 'Flixter', 'Cloak of the Necropolis', 903],
#  ['12/22', 'Mano', 'Gauntlets of Annihilation', 902],
#  ['8/9', 'Gaussqt', 'Fortitude of the Scourge', 898],
#  ['8/31', 'Skylarke', 'Shard of the Fallen Stare', 876],
#  ['', 'Jimbodin', 'Eye of the Dead', 875],
#  ['6/7', 'Ezekyle', 'Doomfinger', 872],
#  ['4/27', 'Morty', 'Ring of Qiraji Fury', 870],
#  ['3/1', 'Fatjaws', 'Shroud of Dominion', 860],
#  ['3/8', 'Varros', 'Might of Menethil', 860],
#  ['12/28', 'Oom', 'The Restrained Essence of Sapphiron', 856],
#  ['1/4', 'Rowaine', 'Gem of Trapped Innocents', 853],
#  ['', 'Shaq', 'Hammer of the Twisting Nether', 850],
#  ['', 'Weirdobeardo', 'Nerubian Slavemaker', 849],
#  ['4/26', 'Nieth', 'Cloak of the Necropolis', 840],
#  ['2/8', 'Hamtaro', 'Eye of the Dead', 839],
#  ['3/8', 'Dane', 'Band of Unnatural Forces', 835],
#  ['', 'Ezekyle', 'Seal of the Damned', 831],
#  ['2/15', 'Kibbles', 'Doomfinger', 829],
#  ['8/2', 'Prastinna', 'Eye of the Dead', 828],
#  ['5/31', 'Kibbles', 'Eye of the Dead', 822],
#  ['2/15', 'Morty', 'Gressil, Dawn of Ruin', 819],
#  ['4/5', 'Ezekyle', 'Cloak of the Necropolis', 815],
#  ['', 'Flixter', 'Leggings of Polarity', 808],
#  ['1/12', 'Fatjaws', "Death's Sting", 801],
#  ['', 'Zhenduo', 'Hammer of the Twisting Nether', 800],
#  ['', 'Spicy', 'Gressil, Dawn of Ruin', 800],
#  ['2/23', 'Rogueisme', 'Drake Fang Talisman', 794],
#  ['1/4', 'Dolphin', 'Kingsfall', 793],
#  ['', 'Hetfield', 'Cloak of the Necropolis', 791],
#  ['', 'Jacckal', 'Band of Unnatural Forces', 783],
#  ['5/10', 'Zaek', 'Cloak of the Necropolis', 780],
#  ['5/24', 'Raphael', 'Corrupted Ashbringer', 777],
#  ['3/1', 'Nightsummon', 'Cloak of the Necropolis', 767],
#  ['', 'Varros', 'Kiss of the Spider', 761],
#  ['', 'Hamtaro', 'Hammer of the Twisting Nether', 759],
#  ['3/22', 'Chihua', 'Corrupted Ashbringer', 753],
#  ['2/1', 'Virahl', "Slayer's Crest", 751],
#  ['5/3', 'Yumi', 'Hammer of the Twisting Nether', 750],
#  ['6/22', 'Sobie', 'Jom Gabbar', 750],
#  ['', 'Yumiki', 'Hammer of the Twisting Nether', 744],
#  ['3/30', 'Sandi', 'Gauntlets of Annihilation', 743],
#  ['2/22', 'Shaq', "Sapphiron's Right Eye", 740],
#  ['6/7', 'Nightsummon', 'The Restrained Essence of Sapphiron', 739],
#  ['2/1', 'Tofra', 'Gem of Trapped Innocents', 733],
#  ['', 'Plated', 'Gauntlets of Annihilation', 732],
#  ['7/19', 'Lightbournne', 'Eye of the Dead', 730],
#  ['4/27', 'Skylarke', "Vanquished Tentacle of C'Thun", 727],
#  ['', 'Xorkal', 'Gressil, Dawn of Ruin', 726],
#  ['4/13', 'Tofra', 'Scarab Brooch', 723],
#  ['4/19', 'Freightdawg', "Slayer's Crest", 720],
#  ['3/23', 'Hamtaro', 'Drake Fang Talisman', 716],
#  ['8/9', 'Hadria', 'Cloak of Suturing', 711],
#  ['', 'Lucen', 'Eyestalk Waist Cord', 707],
#  ['', 'Jimbo', 'Cloak of the Necropolis', 705],
#  ['3/23', 'Kibblers', 'Robes of Volatile Power', 702],
#  ['12/22', 'Yumi', 'Dark Storm Gauntlets', 701],
#  ['', 'Hetfield', 'Eyestalk Waist Cord', 700],
#  ['4/19', 'Keen', 'Cloak of the Necropolis', 700],
#  ['', 'Ahimelech', 'Hammer of the Twisting Nether', 700],
#  ['6/15', 'Ashula', 'Choker of the Fire Lord', 696],
#  ['7/12', 'Tuna', 'Iblis, Blade of the Fallen Seraph', 696],
#  ['', 'Ezekyle', 'Dark Storm Gauntlets', 694],
#  ['12/28', 'Haka', 'Wristguards of Vengeance', 694],
#  ['1/11', 'Jack', "Slayer's Crest", 692],
#  ['7/5', 'Ahimelech', 'Eye of the Dead', 692],
#  ['8/9', 'Nuranfu', 'Shroud of Dominion', 691],
#  ['2/2', 'Nieth', 'Empowered Leggings', 690],
#  ['4/12', 'Jack', 'Kingsfall', 689],
#  ['5/17', 'Sillysunders', 'Iblis, Blade of the Fallen Seraph', 683],
#  ['', 'Kibbles', 'Hammer of the Twisting Nether', 676],
#  ['8/31', 'Malekk', 'Gauntlets of Annihilation', 674],
#  ['4/27', 'Mallanim', "Death's Sting", 669],
#  ['7/12', 'Valerick', 'Plated Abomination Ribcage', 669],
#  ['2/22', 'Jimbo', 'Gem of Trapped Innocents', 667],
#  ['2/22', 'Flixter', 'Rime Covered Mantle', 652],
#  ['5/25', 'Blackstabath', "Death's Sting", 650],
#  ['1/25', 'Haka', 'Legplates of Carnate', 650],
#  ['2/15', 'Nuranfu', "Slayer's Crest", 636],
#  ['', 'Hunten', 'Nerubian Slavemaker', 636],
#  ['7/13', 'Hadria', 'Empowered Leggings', 633],
#  ['4/19', 'Silly', "Stormrage's Talisman of Seething", 633],
#  ['', 'Blackstabath', "Slayer's Crest", 627],
#  ['', 'Oom', 'Power of the Scourge', 624],
#  ['2/8', 'Nineteenxx', 'Legplates of Carnate', 618],
#  ['4/13', 'Fatjaws', 'AQR', 615],
#  ['', 'Todger', 'Rime Covered Mantle', 613],
#  ['5/24', 'Prastinna', 'Hammer of the Twisting Nether', 612],
#  ['8/9', 'Manowar', 'Might of Menethil', 612],
#  ['6/22', 'Rogueisme', 'Belt of Never-Ending Agony', 612],
#  ['8/3', 'Hamtaro', 'Belt of Never-Ending Agony', 610],
#  ['5/24', 'Gotnugs', 'Band of Unnatural Forces', 605],
#  ['2/1', 'Oom', 'Phylactery', 600],
#  ['3/8', 'Raphael', 'Hammert of the Twisting Nether', 600],
#  ['2/23', 'Throndil', 'Rejuvinating Gem', 600],
#  ['6/7', 'Shredz', 'Iblis, Blade of the Fallen Seraph', 600],
#  ['7/26', 'Mini Suzuki', 'Hammer of the Twisting Nether', 600],
#  ['8/23', 'Tuko', 'Hammer of the Twisting Nether', 600],
#  ['8/30', 'Hadria', 'Hammer of the Twisting Nether', 599],
#  ['7/20', 'Silly', 'Scarab Brooch', 590],
#  ['1/12', 'Sillysunders', 'Ancient Qiraji Ripper', 584],
#  ['8/3', 'Pookster', 'Gauntlets of Annihilation', 583],
#  ['', 'Fatjaws', 'Badge of the swarmguard', 581],
#  ['8/23', 'Merlin', 'Cloak of the Necropolis', 580],
#  ['1/4', 'Tofra', 'Leggings of Polarity', 576],
#  ['6/28', 'Ezekyle', 'Rime Covered Mantle', 575],
#  ['2/22', 'Saya', "Slayer's Crest", 572],
#  ['', 'Plated', 'Kiss of the Spider', 571],
#  ['6/21', 'Silly', 'Band of Unnatural Forces', 569],
#  ['7/5', 'inuyasha', 'Iblis, Blade of the Fallen Seraph', 565],
#  ['', 'Hadria', 'Ring of Faith', 563],
#  ['', 'Raphaerl', 'Might of Menethil', 560],
#  ['', 'Mano', 'Band of Unnatural Forces', 556],
#  ['8/31', 'Glowork', 'Scarab Brooch', 555],
#  ['1/12', 'Glowork', 'Badge of the Swarmguard', 555],
#  ['7/5', 'Haka', 'Might of Menethil', 550],
#  ['3/22', 'Silly', 'Castigator', 550],
#  ['', 'Haka', 'Shroud of Dominion', 550],
#  ['6/29', 'Prastinna', 'Rejuvinating Gem', 550],
#  ['', 'Varros', 'Band of Unnatural Forces', 550],
#  ['', 'Alishia', 'Gauntlets of Annihilation', 547],
#  ['8/23', 'Mallanim', 'Iblis, Blade of the Fallen Seraph', 546],
#  ['3/29', 'Nineteen', 'Girdle of the Mentor', 545],
#  ['5/31', 'Rogueisme', 'Band of Unnatural Forces', 540],
#  ['6/7', 'Nuranfu', 'Band of Unnatural Forces', 536],
#  ['4/20', 'Aetherium', 'Chromatic Boots', 530],
#  ['6/14', 'Raphael', 'Shroud of Dominio', 528],
#  ['5/4', 'Malekk', 'Chromatic Boots', 526],
#  ['', 'Kookeyz ', 'Cloak of the Necropolis', 526],
#  ['', 'Varros', "Slayer's Crest", 524],
#  ['1/12', 'Remembrancer', 'Sceptor of the False Prophet', 524],
#  ['4/13', 'Glowork', 'Jom Gabbar', 522],
#  ['12/21', 'Varros', 'Cloak of the Necropolis', 520],
#  ['3/30', 'Vav', 'Scarab Brooch', 519],
#  ['3/1', 'Nineteenxx', 'Iblis, Blade of the Fallen Seraph', 518],
#  ['3/2', 'Rocksteady', "Death's Sting", 514],
#  ['1/4', 'Jimbo', 'The Restrained Essence of Sapphiron', 511],
#  ['', 'Boenita', "Sapphiron's Left Eye", 511],
#  ['', 'Wumbo', 'Might of Menethil', 511],
#  ['', 'Tofra', 'Wraith Blade', 510],
#  ['', 'Haka', 'Kingsfall', 508],
#  ['6/7', 'Todger', 'Leggings of Polarity', 505],
#  ['3/29', 'Kazic', "Stormrage's Talisman of Seething", 504],
#  ['8/10', 'Bombkush', 'Chromatic Boots', 502],
#  ['1/18', 'Nuranfu', 'Maul of the Redeemed Crusader', 501],
#  ['5/3', 'Ismagu', 'Iblis, Blade of the Fallen Seraph', 501],
#  ['3/30', 'Darkphate', 'Jom Gabbar', 500],
#  ['', 'Chihua', 'Hammer of the Twisting Nether', 500],
#  ['', 'Jimbo', 'Leggings of Polarity', 500],
#  ['8/9', 'Gamuza', 'Iblis, Blade of the Fallen Seraph', 500],
#  ['', 'Ezekyle', 'Restrained Essence of Sapph', 500],
#  ['', 'Dane', 'Kiss of the Spider', 498],
#  ['12/22', 'Sandi', 'Badge of the Swarmguard', 492],
#  ['5/17', 'Respira', 'Nerubian Slavemaker', 488],
#  ['7/19', 'Vermora', 'Shroud of Dominion', 486],
#  ['2/8', 'Respiras', 'Iblis, Blade of the Fallen Seraph', 485],
#  ['', 'Hashie', 'Badge of the Swarmguard', 483],
#  ['3/22', 'Kazik', 'Shroud of Dominion', 481],
#  ['2/2', 'Ahi', 'Onslaught Girdle', 481],
#  ['', 'Shaq', 'Ring of Faith', 480],
#  ['', 'Rogueisme', 'bonescythe ring', 478],
#  ['6/22', 'Nightsurviv', 'Bracelets of Royal Redemption', 470],
#  ['', 'Rella', 'Corrupted Ashbringer', 469],
#  ['', 'Flixter', "Sapphiron's Left Eye", 467],
#  ['2/15', 'Lorn', 'Band of Unnatural Forces', 466],
#  ['1/18', 'Nightsummon', 'Leggings of Polarity', 465],
#  ['6/8', 'Holyskanks', 'scarab brooch', 465],
#  ['', 'Haka', 'Band of Unnatural Forces', 462],
#  ['6/8', 'blackstabath', 'cloak of concentrated hatred', 460],
#  ['3/15', 'Throndil', 'Might of Menethil', 460],
#  ['1/12', 'Keen', "Burrower's Shell", 458],
#  ['3/16', 'Nightsummon', "Amulet of Vek'nilash", 453],
#  ['2/22', 'Eedz', 'Nerubian Slavemaker', 450],
#  ['5/11', 'BLToaster', 'Eyestalk Waist Cord', 450],
#  ['', 'Don', 'Breastplate of Annihilation', 450],
#  ['7/26', 'Ismagu', 'Shroud of Dominion', 450],
#  ['5/31', 'Aetherium', "Stormrage's Talisman of Seething", 449],
#  ['', 'Oom', 'Cloak of the Necropolis', 449],
#  ['2/1', 'Todger', 'Leggings of Polarity', 448],
#  ['1/11', 'Kibbles', 'Gem of Trapped Innocents', 444],
#  ['7/26', 'Inuyasha', 'Plated Abomination Ribcage', 444],
#  ['8/10', 'Mallanim', "Striker's Mark", 444],
#  ['6/28', 'Spooge', 'Gem of Trapped Innocents', 440],
#  ['2/9', 'Spooge', 'Dark Storm Gauntlets', 439],
#  ['3/1', 'Inu', 'The Castigator', 436],
#  ['', 'Tofra', 'The Restrained Essence of Sapphiron', 435],
#  ['4/26', 'Raphael', "Stormrage's Talisman of Seething", 434],
#  ['', 'Thunderhamer', 'Wristguards of Vengeance', 434],
#  ['7/6', 'Mallanim', 'AQR', 432],
#  ['', 'Virahl', 'Desecrated Helmet', 430],
#  ['5/18', 'Glowork', 'Onslaught Girdle', 430],
#  ['3/30', 'Mccauley', 'Breastplate of Annihilation', 430],
#  ['', 'Babayaga', 'nerubian slavemaker', 430],
#  ['', 'Dane', 'Desecrated Legplates', 430],
#  ['4/27', 'Keen', "Eye of C'thun", 430],
#  ['7/12', 'Eze', 'Gem of Trapped Innocents', 428],
#  ['3/30', 'Kibbles', 'Eyestalk Waist Cord', 427],
#  ['7/6', 'Rogueisme', 'Cloak of Concentrated Hatred', 425],
#  ['12/28', 'Respira', 'Soulseeker', 425],
#  ['5/11', 'Nightsurviv', 'Grasp of the Old God', 422],
#  ['', 'Silly', 'Hammer of the Twisting Nether', 422],
#  ['', 'Jack', 'Nerubian Slavemaker', 422],
#  ['', 'Oom', 'Leggings of Polarity', 420],
#  ['8/23', 'Devious', 'Wristguards of Vengeance', 420],
#  ['', 'Nieth', "The Widow's Embrace", 420],
#  ['4/6', 'spooqe', 'Rejuvenating Gem', 420],
#  ['6/21', 'Plated', 'Might of Menethil', 420],
#  ['', 'Brockstar', 'Vanquished tentacles of cthun', 420],
#  ['1/25', 'Tunasubgg', 'Girdle of the Mentor', 420],
#  ['5/10', 'Rowaine', 'Hammer of the Twisting Nether', 420],
#  ['', 'Shaq', 'Desecrated Robe', 420],
#  ['', 'Fatjaws', 'Leggings of Apocalypse', 420],
#  ['8/23', 'Galavant', 'Band of Unnatural Forces', 415],
#  ['3/16', 'Inu', 'Anubisath Warhammer', 415],
#  ['2/1', 'Throndil', "Sapphiron's Right Eye", 412],
#  ['1/18', 'Sandown', 'Might of Menethil', 412],
#  ['', 'Manowar', 'Might of the Scourge', 410],
#  ['', 'Blackstabath', 'Desecrated Legplates', 408],
#  ['6/28', 'skylarke', 'Cloak of the Necropolis', 407],
#  ['6/14', 'Aetherium', 'Band of Unnatural Forces', 403],
#  ['', 'Nuranfu', 'Hammer of the Twisting Nether', 402],
#  ['4/20', 'Easykheal', 'Rejuvenating Gem', 401],
#  ['7/12', 'Galavant', 'Might of Menethil', 401],
#  ['8/30', 'Ismago', 'Band of Unnatural Forces', 401],
#  ['6/1', 'Mallanim', "Prestor's Talisman of Connivery", 401],
#  ['', 'Ezekyle', 'Leggings of Polarity', 401],
#  ['', 'Blackhanded', "Widow's Remorse", 401],
#  ['5/24', 'Nuranfu', "Stormrage's Talisman of Seething", 400],
#  ['', 'Tunasubgg', 'Legplates of Carnage', 400],
#  ['6/21', 'Bltoaster', 'Rime Covered Mantle', 400],
#  ['12/28', 'Holyox', 'Wand of the Whispering DeaD', 400],
#  ['3/16', 'Holyskank', 'Sceptor of the False Prophet', 400],
#  ['6/8', 'Respira', 'Eyestalk Waist Cord', 400],
#  ['', 'Hunten', 'Badge ', 400],
#  ['', 'Manowar', 'Badge of the Swarmguard', 400],
#  ['1/18', 'Ezekyle', "Soul Harvester's Bindings", 400],
#  ['', 'Virahl', 'Might of the Scourge', 400],
#  ['3/2', 'Markhunt', 'Barbed Choker', 400],
#  ['', 'Iggsy', 'Girdle of the Mentor', 400],
#  ['3/15', 'Respira', 'Might of the Scourge', 400],
#  ['', 'Tof', 'Rime Covered Mantle', 399],
#  ['4/27', 'Tofra', 'Jom Gabbar', 399],
#  ['', 'Varros', 'Wraith Blade', 397],
#  ['12/21', 'Iggsy', "Stormrage's Talisman of Seething", 395],
#  ['1/26', 'Eedz', 'Carapace of the Old God', 389],
#  ['1/5', 'Throndil', 'Pure Elementium Band', 389],
#  ['5/11', 'Kushbong', "Eye of C'Thun", 388],
#  ['8/23', 'Kushbomb', 'Ring of the Eternal Flame', 387],
#  ['', 'Ezekyle', "Sapphiron's Left Eye", 384],
#  ['1/4', 'Sandi', 'Wristguards of Vengeance', 383],
#  ['', 'Tiric', 'Drillborer Disk', 381],
#  ['', 'Thunderhamer', 'The Castigator', 377],
#  ['5/10', 'Shredz', 'Might of Menethil', 376],
#  ['1/4', 'Thorgene', 'Face of Death', 376],
#  ['5/4', 'Hamtaro', 'Pure Elementium Band', 375],
#  ['', 'Ezekyle', 'Wraith Blade', 375],
#  ['5/25', 'Inuyashasama', "Eye of C'Thun", 375],
#  ['', 'Rumpelz', 'The Castigator', 375],
#  ['8/31', 'Mcrib', "Eye of C'Thun", 375],
#  ['5/11', 'Wumbologi', 'Badge of the Swarmguard', 375],
#  ['', 'Xorkal', 'Iblis, Blade of the Fallen Sereph', 374],
#  ['5/11', 'Markhunt', 'Quick Strike Ring', 374],
#  ['3/1', 'Plated', 'Band of Unnatural Forces', 369],
#  ['', 'Raphael', 'Wristguards of Vengeance', 369],
#  ['', 'Rella', 'Might of the Scourge', 369],
#  ['', 'Nieth', 'Resilience of the Scourge', 369],
#  ['', 'Nieth', 'Neclace of Necropsy', 369],
#  ['3/9', 'Immortaler', 'Chromatically Tempered Sword', 369],
#  ['5/10', 'Malekk', 'Wristguards of Vengeance', 368],
#  ['', 'Hadria', 'Desecrated Robe', 366],
#  ['', 'Kibbles', "Sapphiron's Right Eye", 366],
#  ['3/16', 'Glowork', 'Cloak of the Devoured', 366],
#  ['6/8', 'ismagu', "Eye of C'Thun", 366],
#  ['3/15', 'Ahi', "Sapphiron's Right Eye", 365],
#  ['5/24', 'Medium', "The Phylactery of Kel'Thuzad", 364],
#  ['4/26', 'Saya', 'Misplaced Servo Arm', 364],
#  ['3/30', 'Glowork', 'Shard of the Fallen Star', 363],
#  ['', 'Cypris', "Prestor's Talisman of Canniveery", 360],
#  ['3/23', 'Ahi', 'Chromatically Tempered Sword', 358],
#  ['', 'Hlista', 'Soulseeker', 358],
#  ['5/10', 'Kibbles', 'Leggings of Polarity', 355],
#  ['6/7', 'Ismagu', 'Nerubian Slavemaker', 355],
#  ['12/28', 'Nightsummon', 'Wraith Blade', 355],
#  ['8/2', 'Valerick', 'Soulstring', 352],
#  ['', 'Rogueisme', 'Jom Gabbar', 352],
#  ['5/31', 'Kazic', 'Iblis, Blade of the Fallen Seraph', 351],
#  ['', 'Keen', 'Power of the Scourge', 350],
#  ['5/3', 'Nuranfu', 'Might of Menethil', 350],
#  ['6/22', 'Morty', "Eye of C'Thun", 350],
#  ['2/9', 'Ezekyle', 'Fetish of the Sand Reaver', 350],
#  ['8/17', 'Gamuza', "Eye of C'Thun", 350],
#  ['', 'Respira', 'Maladath', 350],
#  ['3/23', 'Markhunt', 'Askhandi', 350],
#  ['', 'Cypris', 'Shroud of Dominion', 350],
#  ['1/12', 'Virahl', "Eye of C'Thun", 350],
#  ['4/5', 'Respira', 'Hammert of the Twisting Nether', 350],
#  ['3/29', 'Jimbo', 'Seal of the Damned', 350],
#  ['8/23', 'Jyro', 'Plated Abomination Ribcage', 350],
#  ['4/19', 'Throndil', 'Libram of Light', 350],
#  ['', 'Haka', 'Girdle of the Mentor', 350],
#  ['5/3', 'Clonkx', 'Wristguards of Vengeance', 350],
#  ['', 'Alishia', 'Band of Unnatural Forces', 348],
#  ['4/5', 'Nineteen', 'Might of Menethil', 346],
#  ['7/19', 'BLT', "The Soul Harvester's Bindings", 346],
#  ['6/22', 'Inu', 'Ring of the Qiraji Fury', 345],
#  ['3/29', 'Raphael', 'Might of the Scourge', 343],
#  ['3/16', 'Fatjaws', "Burrower's Shell", 341],
#  ['6/29', 'Shredz', 'Chromatic Boots', 336],
#  ['7/5', 'Zaek', 'Soulseekr', 336],
#  ['', 'Rogueisme', 'Iblis, Blade of the Fallen Seraph', 335],
#  ['', 'Brockstar', 'Choker of the FIre Lord', 333],
#  ['2/22', 'Spooge', 'Phylactery', 333],
#  ['3/1', 'Rowaine', "The Soul Harvester's Bindings", 333],
#  ['7/6', 'Nuranfu', 'Ring of Qiraji Fury', 333],
#  ['7/19', 'Merlinsbeard', 'Frostfire Ring', 332],
#  ['8/30', 'Yumi', 'Cloak of the Necropolis', 331],
#  ['', 'Sayapologize', 'Band of Unnatural Forces', 330],
#  ['6/1', 'Glowork', 'Band of Accuria', 330],
#  ['5/18', 'Tuko', 'Pauldrons of Transcendence', 328],
#  ['4/19', 'Eedz', 'Phylactery', 327],
#  ['7/19', 'Kazicx', 'Band of Unnatural Forces', 326],
#  ['6/14', 'Shredz', 'The Castigator', 326],
#  ['2/22', 'Ismagu', 'Might of the Scourge', 325],
#  ['5/17', 'Thondil', 'Band of Unanswered Prayers', 325],
#  ['2/8', 'Tuna', "Stormrage's Talisman of Seething", 325],
#  ['8/10', 'Lightborn', 'LGG', 324],
#  ['5/10', 'Lightbornne', 'Cloak of Suturing', 322],
#  ['7/20', 'Shredz', "Eye of C'Thun", 322],
#  ['', 'Ezekyle', 'Cloak of the Devoured', 320],
#  ['6/1', 'Glowork', 'Chromatic Boots', 320],
#  ['', 'Keen', 'phylactery', 316],
#  ['5/11', 'Sandi', 'Barbed Choker', 316],
#  ['5/3', 'Keen', 'Loatheb Reflection', 315],
#  ['', 'Shaq', 'Wand of the Whispering Dead', 314],
#  ['', 'Fatjaws', 'Harbinger of Doom', 310],
#  ['7/6', 'Kushbomb', "Royal Sceptor of Vek'lor", 310],
#  ['', 'Inuyasha', 'Chromatically Tempered Sword', 307],
#  ['6/14', 'Hadria', "The Phylactery of Kel'Thuzad", 306],
#  ['', 'Hashie', 'The Castigator', 306],
#  ['', 'Flowork', 'Phylactery', 306],
#  ['', 'Todger', 'Doomfinger', 306],
#  ['', 'Varros', 'Wristguards of Vengeance', 305],
#  ['6/22', 'Glowork', "Ritssyn's RIng of Chaos", 304],
#  ['', 'Keen', "amulet of vek'nilash", 304],
#  ['4/12', 'Aetherium', 'Wristguards of Vengeance', 303],
#  ['7/26', 'Kazic', 'Might of the Scourge', 302],
#  ['12/22', 'Remembrancer', "Don Rigoberto's Lost Hat", 301],
#  ['1/25', 'Rogueisme', 'Phylactery', 301],
#  ['', 'Ccheetzaz', 'Chromatically Tempered Sword', 301],
#  ['', 'Zhendou', 'Desecrated Headpiece', 301],
#  ['6/8', 'Okor', 'Quick Strike Ring', 301],
#  ['6/28', 'Iggy', 'Might of the Scourge', 301],
#  ['2/23', 'Floraldyn', 'Ashkhandi, Greatsword of my Ass', 300],
#  ['6/21', 'Flixter', "The Soul Harvester's Bindings", 300],
#  ['6/15', 'Kushbomb', 'Netherwind Robes', 300],
#  ['12/21', 'Virahl', 'Might of the Scourge', 300],
#  ['', 'Kulmirik', 'Mark of Cthun', 300],
#  ['', 'Boenita', 'Leggings of Polarity', 300],
#  ['4/13', 'Daryas', "Eye of C'Thun", 300],
#  ['6/21', 'Kushbomb', 'Phylactery', 300],
#  ['5/3', 'Gaussqt', 'Soulstring', 300],
#  ['', 'Kookeyz', 'Bracers of Arcane Accuracy', 300],
#  ['4/19', 'Spooge', 'Soulseeker', 300],
#  ['1/26', 'Rogueisme ', 'Eye of Cthun', 300],
#  ['7/27', 'Fatjaws', "Prestor's Talisman of Cannivery", 300],
#  ['3/1', 'Kulmirik', 'Power of the Scourge', 300],
#  ['', 'Sayapologize', 'Might of the Scourge', 300],
#  ['', 'Fatjaws', 'Bonescythe Ring', 300],
#  ['3/15', 'Morty', 'Phylactery', 300],
#  ['', 'Kulmirik', 'Rime Covered Mantle', 300],
#  ['5/25', 'Lightbornne', 'Legplates of Blazing Light', 300],
#  ['1/11', 'Spooqe', 'Band of the Inevitable', 299],
#  ['', 'Dane', 'Kingsfall', 299],
#  ['', 'Yumi', 'Warmth of Forgiveness', 299],
#  ['6/7', 'Jimbo', 'Power of the Scourge', 299],
#  ['', 'Tiric', 'Breastplate of Annihilation', 299],
#  ['7/6', 'Jimbo', "The Burrower's Shell", 299],
#  ['7/5', 'Skylark', 'Power of the Scourge', 298],
#  ['3/29', 'Throndil', 'Plated Abomination Ribcage', 297],
#  ['8/30', 'Zak', 'Power of the Scourge', 296],
#  ['', 'Manowar', 'Wristguards of Vengeance', 291],
#  ['1/19', 'Legits', 'Brutality Blade', 291],
#  ['8/30', 'Ismagu', 'Might of Menethil', 290],
#  ['', 'Nightsummon', 'Wand of Fates', 289],
#  ['1/4', 'Varros', 'Might of the Scourge', 289],
#  ['7/19', 'Devious', 'Soulstring', 288],
#  ['', 'Tiric', 'Lifegiving Gem', 283],
#  ['2/2', 'Cumon', 'Brutality Blade', 282],
#  ['6/14', 'Iggy', 'wristguard of vengeance', 278],
#  ['6/28', 'Skylarke', 'Warmth of Forgiveness', 277],
#  ['4/12', 'Malekk', 'Ghoul Skin Tunic', 276],
#  ['', 'Plated', 'Rejuvinating Gem', 276],
#  ['8/31', 'Lightborn', 'Belt of Never-Ending Agony', 276],
#  ['', 'Respira', 'Band of Unnatural Forces', 275],
#  ['', 'Sayapologize', 'Drake Fang Talisman', 272],
#  ['3/29', 'Silly', 'Phylactery', 270],
#  ['', 'Raphael', 'Girdle of the Mentor', 270],
#  ['3/30', 'Ahi', "Eye of C'Thun", 270],
#  ['5/3', 'Chihua', 'The Face of Death', 269],
#  ['', 'Toframadur', "Neltharion's Tear", 269],
#  ['4/12', 'Prastinna', "Sapph's Right Eye", 269],
#  ['', 'Nightsummon', 'Eye of Cthun', 269],
#  ['', 'Dinkkle', 'Dark Storm Gauntlets', 269],
#  ['', 'Rowaine', 'Power of the Scourge', 269],
#  ['', 'Hamtaro', 'Leggings of Apocalypse', 268],
#  ['', 'Volo', 'Desecrated Shoulderpads', 268],
#  ['5/11', 'Mallanim', 'Cloak of Concentrated Hatred', 268],
#  ['', 'Sayberr', 'Desecrated Tunic', 266],
#  ['', 'Volo', 'Desecrated Circlet', 261],
#  ['6/1', 'Sandi', 'Maladath, Runed Blade of the Black Flight', 260],
#  ['', 'Keen', 'Desecrated Circlet', 260],
#  ['2/9', 'Sandown', 'Mark of Cthun', 260],
#  ['3/22', 'Jimbo', 'Power of the Scourge', 259],
#  ['7/26', 'Spooge', 'Seal of the Damned', 258],
#  ['', 'Nieth', 'Desecrated Tunic', 257],
#  ['', 'Dinkkle', 'Desecrated Circlet', 257],
#  ['', 'Nightsummon', "Sapphiron's Left Eye", 256],
#  ['5/24', 'Ismago', 'Might of the Scourge', 255],
#  ['6/7', 'Yumi', 'Wraith Blade', 255],
#  ['5/24', 'BLT', 'Wraith Blade', 255],
#  ['', 'Keen', 'Wand of Fates', 255],
#  ['8/9', 'Begs', 'Plated Abomination Ribcage', 255],
#  ['7/13', 'Nuranfu', 'Pure Elementium Band', 254],
#  ['', 'Dolphin', 'Might of the Scourge', 253],
#  ['6/8', 'Flowork', "vanquished tentacle of c'thun", 252],
#  ['6/21', 'valerick', 'The Castigator', 252],
#  ['', 'Dolphin', 'Nerubian Slavemaker', 252],
#  ['', 'Valerick', 'Eye of Cthun', 251],
#  ['', 'Yumi', 'Rejuvenating Gem', 251],
#  ['1/25', 'Remembrancer', 'Cloak of Suturing ', 251],
#  ['3/16', 'Ismago', 'Quick Strike Ring', 251],
#  ['', 'Kulmirik', 'Desecrated Robe', 250],
#  ['4/20', 'Bltoaster', 'Staff of the Shadow Flame', 250],
#  ['3/22', 'Vav', 'Might of the Scourge', 250],
#  ['4/12', 'Inu', 'Legplates of Carnage', 250],
#  ['1/12', 'Respira', 'Fetish of the Sand Reaver', 250],
#  ['', 'Respirua', 'The Face of Death', 250],
#  ['8/30', 'Pookstar', 'Phylacery', 250],
#  ['12/21', 'Cuminmei', 'Shield of Condemnation', 250],
#  ['', 'Wumbo', "Stormrage's Talisman of Seething", 250],
#  ['8/30', 'Respira', 'Might of the Scourge', 250],
#  ['2/15', 'Rocksteady', 'Might of the Scourge', 250],
#  ['1/25', 'Respira', "The Soul Harvester's Bindings", 250],
#  ['', 'Respira', 'Barbed Choker', 250],
#  ['2/9', 'Hadria', 'Bracelets of Royal Redemption', 250],
#  ['', 'Brockstar', 'Band of Unanswered Prayers', 250],
#  ['', 'Ezekyle', 'Desecrated Robe', 250],
#  ['8/2', 'Shredz', 'Might of the Scourge', 250],
#  ['', 'Respira', 'Desecrated Tunic', 250],
#  ['1/12', 'Throndil', 'Ring of the Qiraji Fury', 250],
#  ['', 'Kulmirik', "Sapphiron's Left Eye", 250],
#  ['8/17', 'Sephirath', 'Eyestalk Waist Cord', 250],
#  ['4/20', 'Lightbournne', 'Choker of the Fire Lord', 250],
#  ['4/13', 'Markhunt', 'Qiraji Bindings of Command', 250],
#  ['', 'Hadria', 'Eye of Cthun', 250],
#  ['2/8', 'Varros', 'Shroud of Dominion', 249],
#  ['8/24', 'Lightborn', 'Chromatically Tempered Sword', 248],
#  ['', 'Yumiki', 'Cloak of Suturing', 243],
#  ['', 'Yumiki', 'Desecrated Circlet', 242],
#  ['', 'Keen', 'Desecrated Robe', 241],
#  ['', 'Lucen', 'Staff of the Shadow Flame', 240],
#  ['5/17', 'Throdn', 'Might of the Scourge', 240],
#  ['8/30', 'koneko', 'shroud of dominion', 240],
#  ['3/1', 'Saya', 'Nerubian Slavemaker', 240],
#  ['', 'Tof', 'Power of the Scourge', 240],
#  ['8/16', 'Manowar', 'Nerubian Slavemaker', 240],
#  ['2/15', 'Tuna', 'The Castigator', 238],
#  ['', 'Yumiki', 'Band of Unanswered Prayers', 238],
#  ['', 'Hadria', 'Warmth of Forgiveness', 237],
#  ['', 'Mav', 'Eye of Cthun', 236],
#  ['', 'Blackstabatrh', 'Desecrated Breastplate', 236],
#  ['2/2', 'Flowork', 'Choker of the Fire Lord', 235],
#  ['3/22', 'Todger', 'Band of the Inevitable', 234],
#  ['', 'Fatjaws', 'Desecrated Gauntlets', 232],
#  ['', 'Fatjaws', 'Desecrated Sabatons', 230],
#  ['', 'Manowar', 'Chromatic Boots', 230],
#  ['', 'Keen', 'Brimstone Staff', 230],
#  ['2/9', 'Fatjaws', 'Eye of Cthun', 226],
#  ['3/22', 'Vav', 'Phylactery', 226],
#  ['4/26', 'Gamuza', 'Might of the Scourge', 225],
#  ['3/1', 'Gamuza', 'Phylactery', 225],
#  ['', 'Haka', 'phylactery', 225],
#  ['', 'Sardinas', 'Band of Unanswered Prayers', 224],
#  ['', 'Mavmoney', 'cloak of the devoured', 224],
#  ['', 'Tofra', 'Frostfire Ring', 223],
#  ['3/16', 'Ismago', 'Eye of Cthun', 222],
#  ['12/22', 'Tofra', "Eye of C'Thun", 222],
#  ['3/1', 'Prastinna', 'Warmth of Forgiveness', 222],
#  ['', 'Tofra', "Sapphiron's Left Eye", 222],
#  ['', 'Toframadur', 'Eyestalk Waist Cord', 222],
#  ['1/18', 'Biggerbill', 'Phylactery', 221],
#  ['3/2', 'Remembrancer', "Eye of C'thun", 220],
#  ['5/25', 'Ahi', 'Boots of the Fallen Hero', 220],
#  ['5/25', 'Fatjaws', "Ring of Emperor Vek'lor", 220],
#  ['', 'Kibbles', 'Rejuv Gem', 220],
#  ['5/24', 'Nightsurviv', "Sapphiron's Right Eye", 219],
#  ['', 'Hunten', 'Soulstring', 219],
#  ['', 'Wumbo', 'Iblis, Blade of the Fallen Sereph', 218],
#  ['', 'Volho', 'Band of Accuria', 217],
#  ['6/14', 'Clonkx', "The Widow's Embrace", 216],
#  ['', 'Kibbles', "Mish'undare, Circlet of the Mind Flayer", 213],
#  ['12/22', 'Flowork', 'Carapace of the Old God', 212],
#  ['', 'Flixter', 'Power of the Scourge', 212],
#  ['8/30', 'Yumi', 'Eye of Diminution', 211],
#  ['', 'Ismagu', 'phylactery', 211],
#  ['', 'Blackstabath', 'Desecrated Bracers', 210],
#  ['', 'Hunten', 'Desecrated Spaulders', 210],
#  ['4/13', 'Legits', 'Carapace of the old god', 209],
#  ['', 'Hamtaro', 'End of Dreams', 207],
#  ['', 'Plated', 'Shard of the Fallen Star', 207],
#  ['', 'Keen', 'Fortitude of the Scourge', 206],
#  ['', 'Volo', 'Grasp of the Old God', 205],
#  ['3/29', 'Jimbo', 'Band of the Inevitable', 205],
#  ['', 'Mavmoney', "The Soul Harvester's Bindings", 204],
#  ['1/25', 'Plated', 'Wristguards of Vengeance', 203],
#  ['', 'Valerick', 'Carapace of the Old God', 203],
#  ['', 'Kulmirik', 'Chromatic Boots', 202],
#  ['8/3', 'BLT', "Royal Sceptor of Vek'lor", 202],
#  ['', 'Tiric', "Styleen's Impeding Scarab", 202],
#  ['12/28', 'Iggs', 'Soulstring', 202],
#  ['1/11', 'Jimbo', 'Phylactery', 201],
#  ['3/23', 'Ismagu', "Prestor's Talisman of Connivery", 201],
#  ['3/2', 'Yumi', 'Bracelets of Royal Redemption', 201],
#  ['7/6', 'Kindbud', "Eye of C'Thun", 201],
#  ['', 'Dinkkle', 'Desecrated Sandals', 201],
#  ['', 'Blackhanded', 'Face of Death', 201],
#  ['8/3', 'Valerick', "Eye of C'Thun", 201],
#  ['2/16', 'Silly', 'Fetish of the Sand Reaver', 201],
#  ['4/26', 'Holyskank', 'Midnight Haze', 201],
#  ['1/19', 'Tukobonk', "Bonereaver's Edge", 201],
#  ['', 'Thunderhamer', 'Larvae of the Great Worm', 201],
#  ['7/12', 'Devious', "The Phylactery of Kel'Thuzad", 201],
#  ['', 'Shredz', 'Plated Abomination Ribcage', 200],
#  ['', 'Respira', 'Chromatic Boots', 200],
#  ['', 'Filox', 'Desecrated Breastplate', 200],
#  ['', 'Sardinas', 'Jom Gabbar', 200],
#  ['', 'Manowar', 'Girdle of the Mentor', 200],
#  ['', 'Respira', 'Band of Reanimation', 200],
#  ['', 'Silly', 'Necklace of Necropsy', 200],
#  ['', 'Ezekyle', 'Ring of the Eternal Flame', 200],
#  ['', 'Gamuza', 'Desecrated Boots', 200],
#  ['7/5', 'BLT', 'Eye of Diminution', 200],
#  ['7/26', 'Light', 'Libram of Light', 200],
#  ['8/9', 'BLT', 'Power of the Scourge', 200],
#  ['', 'Thiccrae', 'Phylactery', 200],
#  ['4/5', 'Morty', 'The Castigator', 200],
#  ['', 'Jimbodin', 'libram of light', 200],
#  ['2/8', 'Kulmirik', "Soul Harvester's Bindings", 200],
#  ['7/5', 'Hadria', 'Band of Unanswered Prayers', 200],
#  ['7/27', 'Rowaine', 'Cauterizing Band', 200],
#  ['12/28', 'Mano', 'Phylactery', 200],
#  ['5/25', 'Lightbornne', "Regenerating Belt of Vek'nilash", 200],
#  ['2/1', 'Jimbo', 'Power of the Scourge', 200],
#  ['', 'Brockstar', "Loatheb's Reflection", 200],
#  ['1/18', 'Immortaler', 'Shroud of Dominion', 200],
#  ['7/13', 'Sobia', 'Band of Accuria', 200],
#  ['', 'Manowar', 'Plated Abomination Ribcage', 200],
#  ['', 'Gamuza', 'Band of Accuria', 200],
#  ['4/19', 'Lightbornne', 'The End of Dreams', 200],
#  ['2/23', 'Sandi', 'Archimetros Ring of Reckoning', 200],
#  ['7/27', 'Ismagu', 'Lifegiving Gem', 200],
#  ['2/2', 'Remembrancer', 'Pure Elementium Band', 200],
#  ['6/8', 'bltoaster', 'Fetish of sandreaver', 200],
#  ['', 'Alishia', 'Plated Abomination Ribcage', 200],
#  ['', 'Gamuza', "Prestor's Talisman of Connivery", 200],
#  ['', 'Darkphate', 'Ring of the Godslayer', 200],
#  ['', 'Tofra', "Widow's Embrace", 199],
#  ['5/31', 'Lightbornne', 'Necklace of Necropocy', 199],
#  ['', 'Lucen', 'Soulseeker', 199],
#  ['7/12', 'Shredz', 'Soulstring', 196],
#  ['7/12', 'Kushbomb', 'Power of the Scourge', 196],
#  ['', 'Mav', 'Power of the Scourge', 196],
#  ['5/17', 'Hamtaro', "Sapphiron's Right Eye", 195],
#  ['', 'Mavmoney', 'Wand of Fates', 194],
#  ['7/5', 'Shredz', 'Ghoul Skin Tunic', 194],
#  ['', 'Mav', 'Brimstone Staff', 194],
#  ['1/25', 'Biggerbill', 'Might of the Scourge', 191],
#  ['', 'Thorbardin', 'Mightnight Haze', 191],
#  ['5/17', 'Kushbomb', 'Soulseeker', 190],
#  ['4/26', 'Nuranfu', 'Shield of Condemnation', 190],
#  ['', 'Kibbles', 'Seal of the Damned', 190],
#  ['7/26', 'Silly', "The Widow's Embrace", 190],
#  ['', 'Yumiki', 'Ring of Faith', 190],
#  ['2/15', 'Varros', 'Power of the Scourge', 189],
#  ['8/24', 'Spooge', "Schematic: Biznick's ", 187],
#  ['6/7', 'Malekk', 'SOulstring', 187],
#  ['', 'Blackstabath', 'Phylactery', 187],
#  ['', 'Xorkal', 'Qiraji Bindings of Command', 187],
#  ['', 'Boenita', 'Eye of Cthun', 185],
#  ['', 'Manus', 'Desecrated Leggings', 185],
#  ['', 'Boenita', 'Desecrated Circlet', 185],
#  ['7/26', 'Kushbomb', "Sapphiron's Left Eye", 185],
#  ['', 'Mav', 'Desecrated Sandals', 184],
#  ['', 'Hadria', 'Wand of the Whispering Dead', 184],
#  ['2/22', 'Gamuza', 'Hatchet of Sundered Bone', 183],
#  ['3/16', 'Tuko', 'Ring of the Martyr', 181],
#  ['', 'Mav', 'Sharpened Silithid Femur', 181],
#  ['5/17', 'Blt', 'Ring of the Eternal Flame', 180],
#  ['', 'Rogueisme', 'Carapace of the Old God', 180],
#  ['', 'Hadria', 'Desecrated Belt', 180],
#  ['', 'Fatjaws', 'Desecrated Pauldrons', 180],
#  ['5/10', 'Blackstabath', 'Might of the Scourge', 180],
#  ['', 'Boenita', 'Seal of the Damned', 180],
#  ['', 'Thunderhamer', 'Plated Abomination Chestplate', 179],
#  ['8/31', 'Hamtaro', 'Garb of Royal Ascension', 179],
#  ['', 'Saya', 'Claw of the Frost Wyrm', 178],
#  ['', 'Hamtaro', "Eye of C'thun", 177],
#  ['', 'Paddington', 'Desecrated Boots', 177],
#  ['3/22', 'Malekk', 'Legplates of Carnage', 176],
#  ['1/12', 'Mallamin', 'Imperial Qiraji Armaments', 176],
#  ['1/5', 'Dane', 'Band of Accuria', 175],
#  ['', 'Rogueisme', 'Qiraji Bindings of Command', 175],
#  ['6/7', 'Gamuza', 'Claw of the Frost Worm', 175],
#  ['6/14', 'Plated', 'Shield of Condemnation', 175],
#  ['', 'Minda', "Dragonstalker's Breastplate", 175],
#  ['', 'Omgitsvav', 'Phylactery', 175],
#  ['', 'Respira', 'Phylactery', 175],
#  ['7/13', 'Tuko', 'MQG', 174],
#  ['4/27', 'Spooge', 'Boots of Epiphany', 174],
#  ['6/1', 'Raphael', 'Wild Growth Spaulders', 174],
#  ['', 'Develon', "Dragonstalker's Belt", 173],
#  ['1/4', 'Zira', 'Phylactery', 173],
#  ['3/29', 'Yumi', 'Shield of Condemnation', 172],
#  ['1/4', 'Weirdobeardo', 'Cloak of the Scourge', 170],
#  ['5/31', 'Jackkal', 'Might of the Scourge', 170],
#  ['1/11', 'Weirdo', 'Kingsfall', 170],
#  ['', 'Nuranfu', 'Resilience of the Scourge', 170],
#  ['', 'Steezi', 'The Face of Death', 170],
#  ['3/1', 'Eedz', 'Might of the Scourge', 170],
#  ['7/13', 'Urijah', 'Stormrage BOots', 170],
#  ['', 'Toframadur', 'Brimstone Staff', 169],
#  ['7/19', 'Kindbuds', 'Phylacery', 169],
#  ['', 'Plated', 'Desecrated Legguards', 169],
#  ['2/23', 'Tuna', 'Wild Growth Spaulders', 169],
#  ['8/2', 'lightbourne', 'Shield of Condemnation', 169],
#  ['', 'Rowaine', 'Eye of Diminution', 169],
#  ['7/12', 'Iggsy', 'Necklace of Necroposy', 169],
#  ['2/8', 'Brockstar', 'End of Dreams', 169],
#  ['2/1', 'Raphael', 'Necklace of Neckropcy', 169],
#  ['2/16', 'Glowork', 'Robes of the Guardian Saint', 169],
#  ['', 'Nieth', 'guise of the devourer', 169],
#  ['8/2', 'Galavat', 'Cloak of the Scourge', 166],
#  ['', 'Tofra', 'Fetish of the Sand Weaver', 166],
#  ['', 'Blackhanded', "Ring of Emperor Vek'lor", 166],
#  ['', 'Blackstabath', "Eye of C'Thun", 165],
#  ['12/28', 'Valerick', "Widow's Remorse", 165],
#  ['', 'Thunderhamer', 'Fetish of the Sand Reaver', 165],
#  ['', 'Rumplez', 'Icebane Pauldrons', 165],
#  ['', 'Toframadur', 'Eye of Cthun', 164],
#  ['', 'Nightsummon', 'Seal of the Dammed', 162],
#  ['1/18', 'Spooge', "The Widow's Embrace", 161],
#  ['', 'Valerick', 'Onslaught Girdle', 161],
#  ['', 'Keen', 'Bracers of Arcane Accuracy', 160],
#  ['', 'Ezekyle', "Amulet of Vek'nilash", 160],
#  ['', 'Tiric', 'Cloak of Conc Hatred', 157],
#  ['3/22', 'Vav', 'Wristguards of Vengeance', 156],
#  ['3/8', 'Prastinna', 'Cloak of Suturing', 156],
#  ['6/21', 'Plated', 'Might of the Scourge', 155],
#  ['', 'Minda', 'Desecrated Girdle', 155],
#  ['', 'Todger', 'Wand of the Fates', 155],
#  ['1/5', 'Thiccrae', "Bonereaver's Edge", 154],
#  ['8/10', 'Svindrix', "Crul'Shorukh, Edge of Chaos", 154],
#  ['2/15', 'Jimbo', 'Wand of Fates', 153],
#  ['2/22', 'Ismagu', "Widow's Remorse", 152],
#  ['8/23', 'Begs', 'Necklace of Necropsy', 151],
#  ['8/23', 'Troutbully', 'Ring of Redemption', 151],
#  ['4/26', 'Xorkal', 'Soulstring', 151],
#  ['6/7', 'Kazic', "The Phylactery of Kel'Thuzad", 151],
#  ['2/16', 'Silly', 'Larvae of the Great Worm', 151],
#  ['', 'Xorkal', 'phylactery', 151],
#  ['3/1', 'Yumi', 'Ring of Redemption', 151],
#  ['4/12', 'Respira', 'Might of the Scourge', 150],
#  ['7/27', 'Ismago', 'Plans: Lionheart Helm', 150],
#  ['4/26', 'Inu', 'Claw of the Frost Worm', 150],
#  ['', 'Oom', "Mish'undare, Circlet of the ", 150],
#  ['2/15', 'Ezekyle', 'Phylactery', 150],
#  ['', 'Ezekyle', 'Husk of the Old God', 150],
#  ['', 'Manowar', 'Eye of Cthun', 150],
#  ['', 'Sillyprayers', 'Wand of the Whispering Dead', 150],
#  ['7/5', 'BLT', "The Phylactery of Kel'Thuzad", 150],
#  ['4/26', 'Aetherium', 'The Castigator', 150],
#  ['2/2', 'Cumin', "Striker's Mark", 150],
#  ['6/8', 'Okor', 'Barbed Choker', 150],
#  ['', 'Zhenduo', 'Band of Unanswered Prayers', 150],
#  ['', 'Legits', 'Band of Accuria', 150],
#  ['7/13', 'BLT', 'Choker of the Fire Lord', 150],
#  ['', 'Hunten', 'Desecrated Headpiece', 150],
#  ['3/22', 'Nezlol', 'Soulseeker', 150],
#  ['', 'Zekrof', 'Qiraji Bindings of Command', 150],
#  ['8/23', 'Gamuza', 'Boots of Displacement', 150],
#  ['4/26', 'Light', "The Soul Harvester's Bindings", 150],
#  ['8/3', 'Legits', 'Gloves of Enforcement', 150],
#  ['12/28', 'Respira', 'Desecrated Robe', 150],
#  ['', 'Kulmirik', 'Imperial Qiraji Regalia', 150],
#  ['', 'Hunten', 'Phylactery', 150],
#  ['', 'Darkphate', 'Desecrated Legguards ', 150],
#  ['1/11', 'Respira', 'Cloak of Suturing ', 150],
#  ['', 'Brockstar', 'Band of the Inevitable', 150],
#  ['', 'The Castigator', 'The Castigator', 150],
#  ['', 'Weirdobeardo', 'Phylactery', 150],
#  ['', 'Sardinas', 'Barbed Choker', 150],
#  ['', 'Hadria', 'Cloak of Clarity', 150],
#  ['', 'Zekrof', 'Lifegiving Gem', 150],
#  ['', 'Hunten', 'Desecrated Tunic', 150],
#  ['', 'Blackstabath', 'Desecrated Helmet', 150],
#  ['2/22', 'Immortalerr', 'Legplates of Carnage', 150],
#  ['3/8', 'Todger', 'Phylactery', 150],
#  ['4/19', 'Keen', 'Power of the Scourge', 150],
#  ['5/31', 'Ezekyle', 'Power of the Scourge', 150],
#  ['', 'Hadria', 'Desecrated Circlet', 150],
#  ['2/22', 'Gamuza', 'Leggings of Apocalypse', 150],
#  ['6/14', 'Gamuza', 'Harbinger of Doom', 150],
#  ['', 'Zhendou', 'Desecrated Tunic', 150],
#  ['8/23', 'Jyro', 'Phylacery', 150],
#  ['', 'Thunderhamer', 'BP of Annihilation', 146],
#  ['3/23', 'Markhunt', 'Cloak of Draconic Might', 145],
#  ['', 'Hamtaro', "The Widow's Embrace", 145],
#  ['5/17', 'Yumi', 'Wand of Fates', 141],
#  ['', 'Hadria', 'Desecrated Leggings', 140],
#  ['2/2', 'Dane', 'Schematic: Force Reactive Disk', 140],
#  ['1/25', 'Nightsummon', 'Power of the Scourge', 140],
#  ['', 'Sardinas', 'Desecrated Spaulders', 140],
#  ['', 'Donlimon', 'mark of cthun', 140],
#  ['4/13', 'Respira', 'something', 139],
#  ['', 'Rella', 'Iblis, Blade of the Fallen Sereph', 139],
#  ['8/16', 'Hamtaro', 'Gem of Trapped Innocents', 138],
#  ['', 'Toframadur', 'Midnight Haze', 138],
#  ['6/14', 'Silly', "Sapphiron's Right Eye", 137],
#  ['6/29', 'Ginblossom', 'Mishundare', 137],
#  ['4/5', 'Spooge', 'Ring of Faith', 137],
#  ['', 'Tiric', 'Dragonbreath Hand Cannon', 137],
#  ['', 'Tunasubg', 'Plated Abomination Ribcage', 135],
#  ['', 'Keen', 'Desecrated Sandals', 135],
#  ['', 'Keen', 'Soulseeker', 134],
#  ['', 'Ahimelech', "Death's Bargain", 130],
#  ['', 'Gamuza/Respira', 'Desecrated Headpiece', 130],
#  ['', 'Barton', 'Severance', 130],
#  ['', 'Barton', "Noth's Heart", 130],
#  ['', 'Ismago', 'Phylacery', 130],
#  ['', 'Thunderhamer', 'Phylactery', 129],
#  ['4/20', 'Brock', 'Formula: Enchant Weapon - Healing Power', 127],
#  ['', 'Isoncooldown', "Lok'amir il Romanthis", 127],
#  ['8/10', 'Deyada', 'Handguards of Transcendence', 127],
#  ['', 'Xorkal', 'Royal Qiraji Belt', 126],
#  ['', 'Keen', 'Desecrated Leggings', 125],
#  ['3/15', 'Throndil', 'Shield of Condemnation', 125],
#  ['3/30', 'Cascada', 'Formula: Enchant Gloves - Frost Power', 125],
#  ['', 'Keen', "Royal Sceptor of Vek'lor", 125],
#  ['4/19', 'Ezekyle', 'Eye of Diminution', 125],
#  ['', 'Ezekyle', 'Desecrated Circlet', 125],
#  ['8/30', 'Truck', 'Ring of the Dreadnought', 125],
#  ['5/11', 'Kazic', 'Breastplate of Annihilation', 125],
#  ['2/16', 'Tukobonk', 'Mark of Cthun', 124],
#  ['', 'Mav', 'Phylactery', 124],
#  ['', 'Mavmoney', 'Seal of the Damned', 124],
#  ['5/17', 'Spooqe', "Soulharvester's bindings", 123],
#  ['5/25', 'Sandi', 'Ring of the Martyr', 123],
#  ['', 'Shaq', 'Resilience of the Scourge', 123],
#  ['', 'Hadria', 'Desecrated Gloves', 122],
#  ['8/31', 'Yumi', "Amulert of Vek'nilath", 122],
#  ['', 'Thunderhamer', 'Circlet of Applied Force', 122],
#  ['1/19', 'Ahimelech', 'Drake Talon Pauldrons', 122],
#  ['2/16', 'Prastinna', 'Regalia', 122],
#  ['1/19', 'Ahimelech', 'Helm of Endless Rage', 121],
#  ['', 'Xorkal', 'Ghoul Skin Tunic', 121],
#  ['', 'Kookeyz', 'Seal of the Damned', 120],
#  ['', 'Fatjaws', 'Polar Helmet', 120],
#  ['', 'Hadria', 'Qiraji Bindings of Command', 120],
#  ['7/12', 'Sindragona', 'The Face of Death', 120],
#  ['', 'Hunten', 'Claw of the Frost Wyrm', 120],
#  ['7/20', 'Kushbomb', 'Eyestalk Waist Cord', 120],
#  ['', 'Keen', 'Band of the Inevitable', 120],
#  ['', 'Kibbles', 'Vanquished tentacles of cthun', 120],
#  ['1/19', 'Ahimelech', 'Circlet of Applied Force', 120],
#  ['3/16', 'Hamtaro', 'Gloves of Enforcement', 119],
#  ['7/12', 'Hamtaro', 'Rime Covered Mantle', 119],
#  ['', 'Keen', 'Veil of Eclipse', 117],
#  ['', 'Jimbodin', 'Bracelets of Royal Redemption', 117],
#  ['', 'Blackhanded', "Gluth's Missing Collar", 117],
#  ['2/8', 'Biggerbill', 'Castigator', 116],
#  ['', 'Thunderhamerr', 'Imperial Qiraji Armaments', 115],
#  ['1/26', 'Flowork', 'Grasp of the Old God', 115],
#  ['5/17', 'Hadria', 'Eye of Diminution', 115],
#  ['1/25', 'Remembrancer', 'Desecrated Tunic', 115],
#  ['', 'Nieth', 'Desecrated Headpiece', 114],
#  ['', 'Fatjaws', 'Desecrated Legplates', 113],
#  ['4/27', 'Light', 'Ring of the Martyr', 113],
#  ['', 'Kulmirik', 'Azuresong Mageblade', 113],
#  ['7/20', 'Nightsurviv', 'Ring of the Martyr', 112],
#  ['12/22', 'Blackhanded', 'Qiraji Execution Bracers', 112],
#  ['5/17', 'Clonkx', 'Harbinger of Doom', 112],
#  ['4/6', 'Saya', 'Band of accuria', 112],
#  ['6/28', 'Hamtaro', 'Band of the Inveitable', 111],
#  ['7/27', 'Tuko', 'Claw of the Black Drake', 111],
#  ['', 'Dinkkle', 'Desecrated Leggings', 111],
#  ['1/12', 'Flowork', 'Breastplate of Annihilation', 111],
#  ['', 'Varros', 'Band of the Inevitable', 111],
#  ['', 'Rogueisme', "Ouro's Intact Hide", 111],
#  ['', 'Kibbles', "Sapphiron's Left Eye", 110],
#  ['', 'Manowar', 'Onslaught Girdle', 110],
#  ['', 'Xorkal', 'Desecrated Legplates', 110],
#  ['', 'Blackhanded', 'Desecrated Breastplate', 107],
#  ['', 'Hashie', 'Ring of the Qiraji Fury', 107],
#  ['4/13', 'Kushbomb', 'Mana Igniting cord', 107],
#  ['', 'Jimbomane', 'Imperial Qiraji Regalia', 107],
#  ['', 'Yumiki', 'Desecrated Leggings', 105],
#  ['', 'Manus', 'Desecrated Belt', 105],
#  ['', 'Manus', 'Qiraji Bindings of Dominance', 105],
#  ['', 'Kulmirik', 'Ring of the Eternal Flame', 105],
#  ['', 'Mav', 'Band of the Inevitable', 104],
#  ['', 'Valerick', 'Ring of the Godslayer', 103],
#  ['12/21', 'Jib', 'Phylactery', 103],
#  ['', 'Tiric', "Vek'nilash's Circlet", 103],
#  ['', 'Xorkal', "Vek'nilash Circlet", 102],
#  ['4/27', 'Glowork', 'Quick Strike Ring', 102],
#  ['', 'Kulmirik', 'Mana Igniting Cord', 101],
#  ['8/30', 'Dwarflord', "Sadist's Collar", 101],
#  ['', 'Fatjaws', 'Fortitude of the Scourge', 101],
#  ['2/16', 'Silly', 'Boots of the Fallen Hero', 101],
#  ['4/13', 'vav', 'something', 101],
#  ['', 'Valerick', 'Spineshatter', 101],
#  ['3/15', 'Haka', 'Face of Death', 101],
#  ['3/2', 'Ismago', 'Larvae of the Great Worm', 101],
#  ['8/23', 'Troutbully', 'Glyph of Deflection', 101],
#  ['', 'Silly', 'Cloak of Suturing', 101],
#  ['6/1', 'Valerick', 'Scrolls', 101],
#  ['3/2', 'Dirtygramps', 'Vanquished Tentacle of Cthun', 101],
#  ['', 'Valerick', 'imperial qiraji regalia', 101],
#  ['', 'Hadria', 'Resilience of the Scourge', 101],
#  ['8/3', 'Valerick', 'Gauntlets of the Righteous Champion', 101],
#  ['2/23', 'Silly', 'Lifegiving Gem', 101],
#  ['8/30', 'Glowork', 'Libram of Light', 101],
#  ['', 'Ismagu', "Striker's Mark", 101],
#  ['', 'Jimbo', 'Desecrated Circlet', 101],
#  ['5/18', 'BLT', 'Band of Forced Concentration', 101],
#  ['5/25', 'Tukobonk', 'Cloak of Clarity', 101],
#  ['', 'Nieth', 'Phylactery', 101],
#  ['12/29', 'Throndil', 'Wild Growth Spaulders', 101],
#  ['5/17', 'Valerick', "Phylactery of Kel'Thuzad", 101],
#  ['', 'Thiccrae', 'Claw of the Frost Worm', 100],
#  ['', 'Hadria', "Vek'nilash's Circlet", 100],
#  ['', 'Zhendup', 'Suturing Cloak', 100],
#  ['4/27', 'Bltoaster', 'Wand of Qiraji Nobility', 100],
#  ['', 'Manowar', 'Quick Strike Ring', 100],
#  ['', 'Charsi', 'Carapace of the Old God', 100],
#  ['4/26', 'Inu', 'Icebane Helmet', 100],
#  ['4/13', 'Holyskank', 'Cloak of the Devoured', 100],
#  ['', 'Wunbrow', "The Soul Harvester's Bindings", 100],
#  ['3/15', 'Rowaine', 'Spaulders of the Grand Crusader', 100],
#  ['4/20', 'Respira', 'Netherwind Robes', 100],
#  ['8/9', 'SHredz', 'Band of Unanswered Prayers', 100],
#  ['7/13', 'Ginblossom', 'Cauterizing Band', 100],
#  ['3/2', 'darkphate', 'Force Reactive Disk Schematic', 100],
#  ['1/25', 'Nineteenxx', 'Nerubian Slavemaker', 100],
#  ['', 'Thunderhamer', "Widow's Remorse", 100],
#  ['8/2', 'Sillyprayers', "The Phylactery of Kel'Thuzad", 100],
#  ['4/19', 'Tofra', 'Ring of Faith', 100],
#  ['1/11', 'Cuminmei', 'Power of the Scourge', 100],
#  ['', 'Minda', 'Imperial Qiraji Armaments', 100],
#  ['8/2', 'Shredz', "The Widow's Embrace", 100],
#  ['3/15', 'Rowaine', 'Leggings of the Grand Crusader', 100],
#  ['2/16', 'Sandi', 'Eye of Cthun', 100],
#  ['3/30', 'Holyskank', 'Ring of the Martyr', 100],
#  ['3/15', 'Virahl', "Widow's Embrace", 100],
#  ['', 'Ezekyle', 'Desecrated Sandals', 100],
#  ['3/2', 'rowaine', 'Force Reactive Disk Schematic', 100],
#  ['4/26', 'Zaek', 'Desecrated Circlet', 100],
#  ['5/3', 'Skylarke', "Sapphiron's Left Eye", 100],
#  ['5/3', 'Skylarke', 'Phylactery', 100],
#  ['4/20', 'Respira', 'Band of Forced Concentration', 100],
#  ['', 'Manowar', "Striker's Mark", 100],
#  ['1/26', 'Cateven', "Don Rigoberto's Lost Hat", 100],
#  ['5/31', 'Holyskank', 'Warmth of Forgiveness', 100],
#  ['', 'Hamtaro', 'Cryptfiend Silk Cloak', 100],
#  ['', 'Hlista', 'Desecrated Circlet', 100],
#  ['', 'Minda', "Maexxna's Fang", 100],
#  ['5/31', 'Okor', "Maexxna's Fang", 100],
#  ['3/22', 'Hadria', "Sapph's Right Eye", 100],
#  ['5/31', 'Tapdatayse', "The Phylactery of Kel'Thuzad", 100],
#  ['', 'Barton', 'Judgement Bindings', 100],
#  ['2/22', 'Eedz', 'Band of Reanimation', 100],
#  ['5/17', 'Clonkx', "Widow's Remorse", 100],
#  ['', 'Tuu', 'Band of Accuria', 100],
#  ['', 'Charsi', 'Desecrated Breastplate', 100],
#  ['5/31', 'Holyskank', 'Soulseeker', 100],
#  ['6/1', 'Legits', 'Cloak of Draconic Might', 100],
#  ['', 'Alishia', 'Signet of the Fallen Defender', 100],
#  ['2/9', 'Ismagu', 'Brutality Blade', 100],
#  ['6/8', 'Clonkx', 'Anubisath Warhammer', 100],
#  ['12/28', 'Cascada', 'Eye of Diminution', 100],
#  ['', 'Alishia', 'Cloak of the Scourge', 100],
#  ['6/8', 'skylarke', 'enchant formula', 100],
#  ['2/15', 'Respiras', 'Wristguards of Vengeance', 100],
#  ['', 'Respira/Gamuza', 'Desecrated Girdle', 100],
#  ['2/8', 'Freightdawg', 'Phylactery', 100],
#  ['5/3', 'Tofra', 'Resilience of the Scourge', 99],
#  ['', 'Paddington', 'Boots of the Shadow Flame', 99],
#  ['8/17', 'Prastinna', 'Cloak of Clarity', 99],
#  ['6/1', 'Irongnome', "Doom's Edger", 99],
#  ['4/5', 'Nuranfu', 'Might of the Scourge', 99],
#  ['', 'Varros', 'Girdle of the Mentor', 99],
#  ['3/29', 'Brock', 'Wand of the Fates', 99],
#  ['', 'Tiric', 'Qiraji Bindings of Command', 99],
#  ['6/28', 'Jimbo', 'Resilience of the Scourge', 99],
#  ['7/13', 'Jimbo', "Styleen's Impeding Scarab", 99],
#  ['', 'Howdruidofme', "Lok'amir ROmanis", 98],
#  ['3/15', 'Cuminmei', 'Cloak of Suturing', 96],
#  ['1/26', 'Legits', 'Qiraji Bindings of Command', 95],
#  ['', 'Mavmoney', 'Garb of Royal Ascension', 94],
#  ['', 'Mav', 'Touch of Frost', 94],
#  ['', 'Mavmoney', 'Band of Forced Concentration', 94],
#  ['', 'Keen', 'Desecrated Shoulderpads', 91],
#  ['7/20', 'Kushbomb', "Amulet of Vek'nilash", 91],
#  ['3/23', 'Tuko', "Styleen's Impeding Scarab", 91],
#  ['', 'Hamtaro', 'Desecrated Tunic', 90],
#  ['', 'Kibbles', 'Mana Igniting Cord', 90],
#  ['', 'Tiric', 'Desecrated Waistguard', 90],
#  ['3/29', 'Nuranfu', 'Power of the Scourge', 90],
#  ['', 'Zekrof', "Ouro's Intact Hide", 90],
#  ['4/5', 'Flowork', 'Cryptfiend Silk Cloak', 90],
#  ['', 'Yumiki', 'Desecrated Shoulderpads', 90],
#  ['5/3', 'Yumi', "The Soul Harvester's Bindings", 89],
#  ['', 'Varros', 'Eye of Cthun', 89],
#  ['', 'Hamtarto', 'Ring of the Martyr', 89],
#  ['3/30', 'Tukobonk', 'Qiraji Execution Bracers', 88],
#  ['12/29', 'Remembrancer', 'Judgment Belt', 88],
#  ['4/20', 'Sillysunders', 'Circle of Applied Force', 88],
#  ['1/26', 'Tuko', 'Qiraji Bindings of Dominance', 88],
#  ['12/29', 'Rogueisme', "Prestor's ", 88],
#  ['7/19', 'Mallanim', 'Desecrated Gauntlets', 86],
#  ['', 'Nightsummon', 'Sharpened Silithis Femur', 85],
#  ['', 'Manus', 'Desecrated Gloves', 85],
#  ['', 'Hadria', 'Desecrated Sandles', 85],
#  ['4/13', 'Throndil', 'Cloak of Clarity', 85],
#  ['', 'Mavmoney', 'Desecrated Gloves', 84],
#  ['', 'Mavmoney', "Vek'nilash's Circlet", 84],
#  ['', 'Mavmoney', 'Midnight Haze', 84],
#  ['5/18', 'Glowork', 'Cauterizing Band', 83],
#  ['', 'Tiric', 'Ooze-ridden Gauntlets', 83],
#  ['', 'Manowar', 'Empowered Leggings', 83],
#  ['2/2', 'Saya', 'Archimetros Ring of Reckoning', 83],
#  ['7/27', 'Rowaine', 'Essence of The Pure', 82],
#  ['', 'Keen', 'Desecrated Gloves', 82],
#  ['3/8', 'Brockstar', "Sapphiron's Left Eye", 82],
#  ['2/16', 'Mallanim', 'Belt of Never-Ending Agony', 81],
#  ['', 'Silly', 'Brimstone Staff', 81],
#  ['', 'Hefestro', 'Boots of the Fallen Hero', 80],
#  ['3/29', 'Throndil', 'Ring of redemption', 80],
#  ['', 'Hlista', 'Desecrated Sandals', 80],
#  ['', 'Hadria', 'Cauterizing Band', 80],
#  ['12/22', 'Magnolia', "Kalimdor's Revenge", 80],
#  ['', 'Xorkal', 'Desecrated Pauldrons', 80],
#  ['5/18', 'Korzeth', "Dragonstalker's Spaulders", 80],
#  ['', 'Yumiki', 'Desecrated Gloves', 80],
#  ['4/27', 'Hamtaro', "Mark of C'Thun", 79],
#  ['3/16', 'Ismago', "Ouro's Intact Hide", 79],
#  ['', 'Minda', 'Skin of the Great Sandworm', 78],
#  ['', 'Thiccrae', 'Quick Strike Ring', 78],
#  ['12/21', 'Jimbo', 'Brimstone Staff', 78],
#  ['8/17', 'Lightborn', 'Breastplate of Annihilation', 78],
#  ['8/30', 'tuko', 'Desecrated Tunic', 77],
#  ['', 'Ahimelech', 'Stormrage Legguards', 77],
#  ...]
